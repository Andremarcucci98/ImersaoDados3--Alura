# %% [markdown]
# <a href="https://colab.research.google.com/github/Andremarcucci98/ImersaoDados3--Alura/blob/main/Imersao_Dados_Aula04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Imersão Dados - Aula 04***
# *   Merge e Análise de Resultados
#
# ####Link do repositório GitHub com os dados utilizados durante a aula:
# *   https://github.com/alura-cursos/imersaodados3/tree/main/dados
#
# ###***Developer:*** André Marcucci Maciel
# ###***GitHub:*** *https://github.com/Andremarcucci98*

# %%
# Importando bibliotecas 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Importando tabela do GitHub
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

#Carregando o conteúdo e descompactando utilizando "compression"
dados = pd.read_csv(url_dados, compression='zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.shape
# Out:
# (23814, 877)

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()

# %%
dados['dose'].unique()

# %%
dados['droga'].unique()

# %%
dados['g-0'].unique()

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['dose'].value_counts()

# %%
mapa = {'droga': 'composto'}
dados.rename(columns=mapa, inplace=True)

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
cod_compostos = dados['composto'].value_counts().index[:5]
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
sns.set()
plt.figure(figsize=(8, 6))
ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'))
ax.set_title('Top 5 compostos')
plt.show()

# %%
len(dados['g-0'].unique())

# %%
dados['g-0'].min()

# %%
dados['g-0'].max()

# %%
dados['g-0'].hist(bins=100)

# %%
dados['g-19'].hist(bins=100)

# %%
dados['g-0'].mean()

# %%
dados.describe()

# %%
dados[{'g-0','g-1'}]

# %%
dados.loc[:, 'g-0':'g-771'].describe()

# %%
dados.loc[:, 'g-0':'g-771'].describe().T['mean'].hist(bins=30)

# %%
dados.loc[:, 'g-0':'g-771'].describe().T['min'].hist(bins=30)

# %%
dados.loc[:, 'g-0':'g-771'].describe().T['max'].hist(bins=30)

# %%
dados.loc[:, 'c-0':'c-99'].describe().T['mean'].hist(bins=50)

# %%
plt.figure(figsize=[10,8])
sns.boxplot(x='g-0', y='tratamento' , data=dados)

# %%
dados['tratamento'].value_counts(normalize=True)

# %%
dados['dose'].value_counts(normalize=True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.bar()

# %%
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# #**Aula 03 - Correlações, causalidade e relações entre genes**

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
pd.crosstab(dados['dose'], dados['tempo'])
# Retorna quantidade de doses x tempo
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g-0'],aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %% [markdown]
# Queremos saber a média do G-0 para quando recebemos uma dose de pequena quantidade, medimos a saída depois de 24h e queremos a média "com_controle" e "com_droga".
# A primeira linha nos informa que a amostra "D1" "com_controle" obteve média de -0.251760, já "com_droga" obteve média de 0.367996.

# %%
dados[['g-0','g-3']]
# Out:
#           g-0     g-3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
sns.scatterplot(x='g-0', y='g-3', data=dados)

# %%
sns.scatterplot(x='g-0', y='g-8', data=dados)

# %%
sns.lmplot(data=dados, x='g-0', y='g-8', line_kws={'color':'red'})

# %%
# Correlação entre g-0 e g-8, separando por tempo e tipo de tratamento
sns.lmplot(data=dados, x='g-0', y='g-8', line_kws={'color':'red'}, col='tratamento', row='tempo', hue='tratamento')

# %%
dados.loc[:,'g-0':'g-771'].corr()
# Out:
#             g-0       g-1       g-2  ...     g-769     g-770     g-771
# g-0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g-1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g-2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g-3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g-4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...         ...       ...       ...  ...       ...       ...       ...
# g-767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g-768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g-769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g-770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g-771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
import numpy as np

corr = dados.loc[:,'g-0':'g-50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr_celular = dados.loc[:,'c-0':'c-50'].corr()

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# #**Aula 04 - Merge e Análise de Resultados**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados['acat_inhibitor'].unique()
# Out:
# array([0, 1])

# %%
contagem_moa = dados_resultados.select_dtypes('int64').sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dados_resultados.drop('id', axis=1).sum(axis=1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultados['n_moa'] = dados_resultados.drop('id', axis=1).sum(axis=1)
dados_resultados['n_moa'] != 0
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 23809     True
# 23810     True
# 23811    False
# 23812     True
# 23813    False
# Name: n_moa, Length: 23814, dtype: bool

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] != 0)
dados_resultados
# Out:
#                  id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0      id_000644bb2                            0  ...      1       True
# 1      id_000779bfc                            0  ...      0      False
# 2      id_000a6266a                            0  ...      3       True
# 3      id_0015fd391                            0  ...      0      False
# 4      id_001626bd3                            0  ...      1       True
# ...             ...                          ...  ...    ...        ...
# 23809  id_fffb1ceed                            0  ...      1       True
# 23810  id_fffb70c0c                            0  ...      1       True
# 23811  id_fffc1c3f4                            0  ...      0      False
# 23812  id_fffcb9e7c                            0  ...      1       True
# 23813  id_ffffdd77b                            0  ...      0      False
#
# [23814 rows x 209 columns]

# %%
dados_combinados = pd.merge(dados, dados_resultados[['id','n_moa', 'ativo_moa']], on='id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
dados_combinados.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
composto_principal = dados_combinados['composto'].value_counts().index[:5]
plt.figure(figsize=(8,6))
sns.boxplot(data = dados_combinados.query('composto in @composto_principal'), y= 'g-0', x='composto', hue='ativo_moa')

# %% [markdown]
# ##**Desafios - Aula 04**

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ###**Desafio 01:** Encontrar o top 10 das ações do MOA (inibidor, agonista,...)

# %%
moa_types = np.unique([col.split('_')[-1] for col in dados_resultados.drop('id',axis=1).columns])
freq = dados_resultados.drop(['id','n_moa','ativo_moa'], axis=1).sum().sort_values(ascending=False)
contador = dict.fromkeys(moa_types,[0])
for name in freq.index:
  contador[name.split('_')[-1]] += freq[name]
count = pd.DataFrame.from_dict(contador).T.rename({0:"count"},axis=1).sort_values(by='count', ascending=False)
count.head(10)
# Out:
#                    count
# inhibitor           9693
# antagonist          3449
# agonist             2330
# blocker              323
# agent                150
# activator            115
# local                 80
# antioxidant           73
# anti-inflammatory     73
# immunosuppressant     73

# %%
moa_ordem = dados_resultados.drop(['id','n_moa','ativo_moa'], axis=1).sum().sort_values(ascending=False)
moa_ordem
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
split_nome = [cont.split('_')[-1]for cont in moa_ordem.index]
split_nome[:10]
# Out:
# ['inhibitor',
#  'inhibitor',
#  'inhibitor',
#  'antagonist',
#  'antagonist',
#  'inhibitor',
#  'antagonist',
#  'antagonist',
#  'inhibitor',
#  'inhibitor']

# %%
contagem_func = pd.DataFrame(data = {'Agente':moa_ordem.index, 'Contagem':moa_ordem, 'Função':split_nome})
contagem_func['Função'] = [row[-1] for row in list(contagem_func['Agente'].str.rsplit('_',1))]
contagem_func
# Out:
#                                                                                 Agente  ...      Função
# nfkb_inhibitor                                                          nfkb_inhibitor  ...   inhibitor
# proteasome_inhibitor                                              proteasome_inhibitor  ...   inhibitor
# cyclooxygenase_inhibitor                                      cyclooxygenase_inhibitor  ...   inhibitor
# dopamine_receptor_antagonist                              dopamine_receptor_antagonist  ...  antagonist
# serotonin_receptor_antagonist                            serotonin_receptor_antagonist  ...  antagonist
# ...                                                                                ...  ...         ...
# protein_phosphatase_inhibitor                            protein_phosphatase_inhibitor  ...   inhibitor
# autotaxin_inhibitor                                                autotaxin_inhibitor  ...   inhibitor
# ...

# %%
contagem_moa_2 = contagem_func.groupby(by='Função').sum().sort_values(by='Contagem', ascending=False)
contagem_moa_2
# Out:
#                    Contagem
# Função
# inhibitor              9693
# antagonist             3449
# agonist                2330
# blocker                 323
# agent                   150
# activator               115
# local                    80
# antioxidant              73
# anti-inflammatory        73
# immunosuppressant        73
# medium                   56
# sensitizer               51
# stimulant                49
# antibiotic               43
# antiprotozoal            36
# antifolate               36
# secretagogue             30
# b                        26
# donor                    26
# antiviral                23
# scavenger                18
# antimalarial             18
# antifungal               13
# antihistamine            12
# analgesic                12
# anticonvulsant           12
# laxative                  6
# diuretic                  6
# antiarrhythmic            6
# steroid                   6

# %%
import plotly.express as px

fig = px.bar(contagem_moa_2, x=contagem_moa_2.index[:20], y=contagem_moa_2['Contagem'][:20], log_y=True, 
             title='Top 10 MOA')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="fdbed17d-6369-4c61-bfda-d56ff72c9825" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fdbed17d-6369-4c61-bfda-d56ff72c9825")) {
#                     Plotly.newPlot(
#                         'fdbed17d-6369-4c61-bfda-d56ff72c9825',
# ...

# %% [markdown]
# Material interessante para plotagem: https://plotly.com/python/plotly-express/

# %% [markdown]
# ###**Desafio 02:** Criar a coluna eh_controle para quando na linha tratamento == com_controle

# %%
dados_combinados['eh_controle'] = (dados_combinados['tratamento'] == 'com_controle')
dados_combinados[:10]
# Out:
#              id tratamento  tempo dose  ...    c-99  n_moa  ativo_moa  eh_controle
# 0  id_000644bb2  com_droga     24   D1  ...  0.4176      1       True        False
# 1  id_000779bfc  com_droga     72   D1  ...  0.7371      0      False        False
# 2  id_000a6266a  com_droga     48   D1  ...  0.6931      3       True        False
# 3  id_0015fd391  com_droga     48   D1  ... -0.8154      0      False        False
# 4  id_001626bd3  com_droga     72   D2  ...  0.7125      1       True        False
# 5  id_001762a82  com_droga     24   D1  ...  1.3990      1       True        False
# 6  id_001bd861f  com_droga     24   D2  ... -0.3179      0      False        False
# 7  id_0020d0484  com_droga     48   D1  ...  0.0260      1       True        False
# 8  id_00224bf20  com_droga     48   D1  ...  0.5543      0      False        False
# 9  id_0023f063e  com_droga     48   D2  ... -2.0000      1       True        False
#
# [10 rows x 880 columns]

# %% [markdown]
# ###**Desafio 03:** Criar três colunas para indicar o tempo 24, 48, 72

# %%
dados_combinados['tempo_24'] = (dados_combinados['tempo'] == 24)
dados_combinados['tempo_48'] = (dados_combinados['tempo'] == 48)
dados_combinados['tempo_72'] = (dados_combinados['tempo'] == 72)
dados_combinados[:10]
# Out:
#              id tratamento  tempo  ... tempo_24 tempo_48  tempo_72
# 0  id_000644bb2  com_droga     24  ...     True    False     False
# 1  id_000779bfc  com_droga     72  ...    False    False      True
# 2  id_000a6266a  com_droga     48  ...    False     True     False
# 3  id_0015fd391  com_droga     48  ...    False     True     False
# 4  id_001626bd3  com_droga     72  ...    False    False      True
# 5  id_001762a82  com_droga     24  ...     True    False     False
# 6  id_001bd861f  com_droga     24  ...     True    False     False
# 7  id_0020d0484  com_droga     48  ...    False     True     False
# 8  id_00224bf20  com_droga     48  ...    False     True     False
# 9  id_0023f063e  com_droga     48  ...    False     True     False
#
# [10 rows x 883 columns]

# %% [markdown]
# ###**Desafio 04:** Estudar sobre combinações de DF:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %% [markdown]
# **concat() ->** Concatenate pandas objects along a particular axis with optional set logic along the other axes. Can also add a layer of hierarchical indexing on the concatenation axis, which may be useful if the labels are the same (or overlapping) on the passed axis number.
# **pandas.concat(objs, axis=0, join='outer', ignore_index=False, keys=None, levels=None, names=None, verify_integrity=False, sort=False, copy=True)**
#
# **append ->** Append rows of other to the end of caller, returning a new object.Columns in other that are not in the caller are added as new columns.
# **DataFrame.append(other, ignore_index=False, verify_integrity=False, sort=False)**
#
# **Database-style DataFrame or named Series joining/merging**
#
# **merge ->** merge is a function in the pandas namespace, and it is also available as a DataFrame instance method merge(), with the calling DataFrame being implicitly considered the left object in the join.
# **DataFrame.merge(right, how='inner', on=None, left_on=None, right_on=None, left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=True, indicator=False, validate=None)**
#
# **join ->** DataFrame.join() is a convenient method for combining the columns of two potentially differently-indexed DataFrames into a single result DataFrame.
# **DataFrame.join(other, on=None, how='left', lsuffix='', rsuffix='', sort=False)**

# %% [markdown]
# ###**Desafio 05:** Fazer análise mais detalhada considerando tempo e dose, para comparar as distribuições. (Escolher uma droga e comparar com o controle nos diferentes tempos e diferentes dosagens)

# %%
controle = dados_combinados[dados_combinados['tratamento']=='com_controle']

# %%
fig, ax = plt.subplots(1,2,figsize=(16,8))
plt.figure(figsize=(12,8))
sns.boxplot(data = dados_combinados.query('composto in @composto_principal'), y='g-0', x='composto', hue='tempo', ax=ax[0])
sns.boxplot(data=controle,y='g-0', x='tempo', hue='dose',ax=ax[1])
ax[0].set_title('G-0 em diferentes compostos e diferentes tempos')
ax[1].set_title('Controle')
# Out:
# Text(0.5, 1.0, 'Controle')

# %% [markdown]
# ###**Desafio 06:** Descobrir se temos algum composto que dependendo da configuração do experimento, ativa ou não ativa algum MOA.

# %%
#Verificando se está tudo OK com o DataFrame
dados_combinados.head()
# Out:
#              id tratamento  tempo  ... tempo_24 tempo_48  tempo_72
# 0  id_000644bb2  com_droga     24  ...     True    False     False
# 1  id_000779bfc  com_droga     72  ...    False    False      True
# 2  id_000a6266a  com_droga     48  ...    False     True     False
# 3  id_0015fd391  com_droga     48  ...    False     True     False
# 4  id_001626bd3  com_droga     72  ...    False    False      True
#
# [5 rows x 883 columns]

# %%
#Separando DataFrame entre "ativos" e "inativos"
dados_teste1 = dados_combinados[['composto', 'ativo_moa']].query('ativo_moa == True')
dados_teste1
# Out:
#         composto  ativo_moa
# 0      b68db1d53       True
# 2      18bb41b2c       True
# 4      7cbed3131       True
# 5      e06749542       True
# 7      8b87a7a83       True
# ...          ...        ...
# 23807  a28556d51       True
# 23808  6c3a459be       True
# 23809  df1d0a5a1       True
# 23810  ecf3b6b74       True
# 23812  8b87a7a83       True
#
# [14447 rows x 2 columns]

# %%
#Dados apenas para MOA's ATIVOS
dados_teste1.describe()
# Out:
#          composto ativo_moa
# count       14447     14447
# unique       2076         1
# top     87d714366      True
# freq          718     14447

# %%
dados_teste2 = dados_combinados[['composto', 'ativo_moa']].query('ativo_moa == False')
dados_teste2
# Out:
#         composto  ativo_moa
# 1      df89a8e5a      False
# 3      8c7f86626      False
# 6      746ca1f5a      False
# 8      952b76dfc      False
# 14     e0cd5c091      False
# ...          ...        ...
# 23801  24c787f29      False
# 23804  74515bfd2      False
# 23806  47dd8f190      False
# 23811  cacb2b860      False
# 23813  972f41291      False
#
# [9367 rows x 2 columns]

# %%
#Dados apenas para MOA's não ativos
dados_teste2.describe()
# Out:
#          composto ativo_moa
# count        9367      9367
# unique       1213         1
# top     cacb2b860     False
# freq         1866      9367

# %%
atividade_moa = dados_combinados[['composto', 'ativo_moa']]
atividade_moa
# Out:
#         composto  ativo_moa
# 0      b68db1d53       True
# 1      df89a8e5a      False
# 2      18bb41b2c       True
# 3      8c7f86626      False
# 4      7cbed3131       True
# ...          ...        ...
# 23809  df1d0a5a1       True
# 23810  ecf3b6b74       True
# 23811  cacb2b860      False
# 23812  8b87a7a83       True
# 23813  972f41291      False
#
# [23814 rows x 2 columns]

# %%
#Dados de todos os compostos
atividade_moa.describe()
# Out:
#          composto ativo_moa
# count       23814     23814
# unique       3289         2
# top     cacb2b860      True
# freq         1866     14447

# %%
#Descobrindo se algum composto é ativado e desativado por um mesmo composto
pd.merge(dados_combinados[['composto','ativo_moa']].query('ativo_moa == True'), dados_combinados[['composto','ativo_moa']].query('ativo_moa == False'), 
         on = 'composto')
# Out:
# Empty DataFrame
# Columns: [composto, ativo_moa_x, ativo_moa_y]
# Index: []

# %% [markdown]
# Todos os compostos ativam (ou não ativam) apenas um MOA, logo não foi possível encontrar resultados plausíveis que indiquem se a configuração do experimento interfere na ativação do MOA.

# %% [markdown]
# ###**Desafio 07:** Descobrir se temos algum composto que dependendo da configuração do experimento, ativa MOAs diferentes.

# %%
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
dados_desafio7 = pd.merge(dados_resultados, dados[['id','composto', 'tempo', 'dose']], on='id')
dados_desafio7
# Out:
#                  id  5-alpha_reductase_inhibitor  ...  tempo  dose
# 0      id_000644bb2                            0  ...     24    D1
# 1      id_000779bfc                            0  ...     72    D1
# 2      id_000a6266a                            0  ...     48    D1
# 3      id_0015fd391                            0  ...     48    D1
# 4      id_001626bd3                            0  ...     72    D2
# ...             ...                          ...  ...    ...   ...
# 23809  id_fffb1ceed                            0  ...     24    D2
# 23810  id_fffb70c0c                            0  ...     24    D2
# 23811  id_fffc1c3f4                            0  ...     48    D2
# 23812  id_fffcb9e7c                            0  ...     24    D1
# 23813  id_ffffdd77b                            0  ...     72    D1
#
# [23814 rows x 212 columns]

# %%
dados_desafio7['cod_rea'] = dados_desafio7[dados_resultados.drop(['id', 'n_moa', 'ativo_moa'], axis=1).columns].astype(str).agg(''.join, axis=1)
dados_desafio7 = dados_desafio7[['composto', 'cod_rea', 'tempo', 'dose']]
dados_desafio7
# Out:
#         composto                                            cod_rea  tempo dose
# 0      b68db1d53  0000000000000000000000000000000000000000000000...     24   D1
# 1      df89a8e5a  0000000000000000000000000000000000000000000000...     72   D1
# 2      18bb41b2c  0000000000000000000000000000000000000000000000...     48   D1
# 3      8c7f86626  0000000000000000000000000000000000000000000000...     48   D1
# 4      7cbed3131  0000000000000000000000000000000000000000000000...     72   D2
# ...          ...                                                ...    ...  ...
# 23809  df1d0a5a1  0000000000000000000000000000000000000000000000...     24   D2
# 23810  ecf3b6b74  0000000000000000000000000000000000000000000000...     24   D2
# 23811  cacb2b860  0000000000000000000000000000000000000000000000...     48   D2
# 23812  8b87a7a83  0000000000000000000000000000000000000000000000...     24   D1
# 23813  972f41291  0000000000000000000000000000000000000000000000...     72   D1
#
# ...

# %%
dados_desafio7.groupby(['composto', 'dose', 'tempo']).nunique().query('cod_rea == 1')
# Out:
#                       cod_rea
# composto  dose tempo
# 00199ff52 D1   24           1
#                48           1
#                72           1
#           D2   24           1
#                48           1
# ...                       ...
# fff7d208d D1   48           1
#                72           1
#           D2   24           1
#                48           1
#                72           1
#
# [18995 rows x 1 columns]

# %%
dados_desafio7.groupby(['composto', 'dose', 'tempo']).nunique().query('contagem == 0')
# Out:
# Empty DataFrame
# Columns: [cod_rea]
# Index: []

# %% [markdown]
# ###**Desafio 08:** Resumo do que você aprendeu com os dados.

# %% [markdown]
# *   join(), merge(), join(), concat()
# *   Formas de combinações usando pandas
# *   Como facilitar seleção de dados usando split()
# *   Montar/Adição de colunas em um DF
# *   Utilização de boxplot para análise de vários índices
# *   Relizar boxplot com
# *   Item da lista
# *   Não foram encontrados compostos que dependessem da configuração de experimentos para obtermos efeitos distintos.
# *   Novas formas de plotar gráficos, link para consulta: https://plotly.com/python/plotly-express/
